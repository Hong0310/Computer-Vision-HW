# %% [markdown]
# # CSE527 Homework 5 Part 1
# **Due date: 11:59 pm EST on May 9, 2022 (Monday)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
# ---
#
# ## Tracking algorithm description
#
# This assignment is based on SiamFC [1] Tracking. The basic idea of [1] is to learn a similarity measurement between target and search space using deep Siamese network. With the learned similarity measurement, both target localization and target scale estimation will be performed on it. In addition, no model update is performed during tracking. **More details can be found in the original paper [1].**
#
# ## Your task
#
# In this assignment, you will find two problems.
# 1. The first one is a standard SiamFC based tracking algorithm. It will be given with several parts incompleted (e.g., the function loading sequence for tracking). You need to complete these parts and make the full tracking algorithm work.
# 2. Second one is based on RGB-Thermal Tracking. In this tracking problem, you will additionally have a Thermal channel alongside the RGB(visible spectrum) image in the video sequences. You need to use this additional information to your advantage to aid the tracking. Again, few missing sections of the code have to be completed here.
#
#
# The incompleted parts will be like this:
#
#   \# description of requirement for this part
#
#   \##########--WRITE YOUR CODE HERE--##########
#
#   ...
#
#   \##########-------END OF CODE-------##########
#
# **NOTE: the pretrained SiamFC model is given, and you just need to use the pretrained model to finish the tracking algorithm.**
#
#
# [1] Fully-Convolutional Siamese Networks for Object Tracking, ECCVW, 2016.

# %% [markdown]
# #Environment set up and data preparation
#
#
#
# 1.   **Install PyTorch 1.1.0 and Pillow 6.0.0.**
#
#   Please install PyTorch 1.1.0 using the following command (By default, latest version of PyTorch is installed on CoLab. Here, we want to use an old version). In addition, you also need to downgrade the Pillow to verion 6.0.0.
#
#   **After finishing, remember to restart runtime, otherwise you may get errors.**

# %%
# install pytorch
# !pip install torch===1.2.0 torchvision==0.4.0 -f https://download.pytorch.org/whl/torch_stable.html

# downgrade pillow
# !pip install pillow==6.0.0

# after executing the above commands, remember to restart runtime
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch===1.2.0 in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: torchvision==0.4.0 in /usr/local/lib/python3.7/dist-packages (0.4.0+cu92)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch===1.2.0) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (6.0.0)
# Requirement already satisfied: pillow==6.0.0 in /usr/local/lib/python3.7/dist-packages (6.0.0)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd "/gdrive/MyDrive/Wang_Hong_113263916_hw/Wang_Hong_113263916_hw5"
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/hw5

# %% [markdown]
# 2.   **Download data and model**
#
# Now lets pull the data into your project root.
# If you are using Google colab, you can simply open each below link and click the "Add to Drive" Icon on the top-right corner of website to add it's shortcut to your current project root.
#
# link for data:
#   1.  https://drive.google.com/open?id=1GH1mDaS6vWXcypbXxqjVxtcQM0XY28lS
#   2. https://drive.google.com/open?id=10lIlhq15W0EuspAk-s-u5JNei1UyEJ-s
#
# link for model:
#   3. https://drive.google.com/open?id=1XhmZWFxth4JDbf_Pd_qezEVRu-D_UPZ8;
#
# link for utility codes:
#   4. https://drive.google.com/open?id=1lUh8GO-wX0rxaxJGLefpute7_YK1Sz7H
#   5. https://drive.google.com/open?id=1A_KbyWcOpl-6cEW7zP0Ub-fE1dVjZSgE;
#
#
# Else, you can manually download the above files to your local project root.

# %% [markdown]
# 3. **Unzip the video sequence using the following commands.**

# %%
# unzip video data from the zip file
# !unzip SiamFCVideo.zip
# !unzip RGB-T234.zip
# Out:
# Archive:  SiamFCVideo.zip
#    creating: SiamFCVideo/
#   inflating: SiamFCVideo/groundtruth_rect.txt
#    creating: SiamFCVideo/img/
#   inflating: SiamFCVideo/img/0001.jpg
#   inflating: SiamFCVideo/img/0002.jpg
#   inflating: SiamFCVideo/img/0004.jpg
#   inflating: SiamFCVideo/img/0005.jpg
#   inflating: SiamFCVideo/img/0006.jpg
#   inflating: SiamFCVideo/img/0008.jpg
#   inflating: SiamFCVideo/img/0009.jpg
#   inflating: SiamFCVideo/img/0010.jpg
#   inflating: SiamFCVideo/img/0011.jpg
#   inflating: SiamFCVideo/img/0012.jpg
#   inflating: SiamFCVideo/img/0013.jpg
#   inflating: SiamFCVideo/img/0014.jpg
#   inflating: SiamFCVideo/img/0016.jpg
#   inflating: SiamFCVideo/img/0017.jpg
#   inflating: SiamFCVideo/img/0018.jpg
#   inflating: SiamFCVideo/img/0019.jpg
#   inflating: SiamFCVideo/img/0021.jpg
#   inflating: SiamFCVideo/img/0023.jpg
#   inflating: SiamFCVideo/img/0024.jpg
#   inflating: SiamFCVideo/img/0026.jpg
#   inflating: SiamFCVideo/img/0028.jpg
#   inflating: SiamFCVideo/img/0030.jpg
#   inflating: SiamFCVideo/img/0031.jpg
#   inflating: SiamFCVideo/img/0032.jpg
#   inflating: SiamFCVideo/img/0033.jpg
#   inflating: SiamFCVideo/img/0035.jpg
#   inflating: SiamFCVideo/img/0036.jpg
#   inflating: SiamFCVideo/img/0038.jpg
#   inflating: SiamFCVideo/img/0039.jpg
#   inflating: SiamFCVideo/img/0040.jpg
#   inflating: SiamFCVideo/img/0042.jpg
#   inflating: SiamFCVideo/img/0044.jpg
#   inflating: SiamFCVideo/img/0045.jpg
#   inflating: SiamFCVideo/img/0047.jpg
#   inflating: SiamFCVideo/img/0048.jpg
#   inflating: SiamFCVideo/img/0049.jpg
#   inflating: SiamFCVideo/img/0050.jpg
#   inflating: SiamFCVideo/img/0052.jpg
#   inflating: SiamFCVideo/img/0054.jpg
#   inflating: SiamFCVideo/img/0056.jpg
#   inflating: SiamFCVideo/img/0057.jpg
#   inflating: SiamFCVideo/img/0058.jpg
#   inflating: SiamFCVideo/img/0060.jpg
#   inflating: SiamFCVideo/img/0062.jpg
#   inflating: SiamFCVideo/img/0063.jpg
#   inflating: SiamFCVideo/img/0064.jpg
#   inflating: SiamFCVideo/img/0065.jpg
#   inflating: SiamFCVideo/img/0066.jpg
#   inflating: SiamFCVideo/img/0067.jpg
#   inflating: SiamFCVideo/img/0068.jpg
#   inflating: SiamFCVideo/img/0070.jpg
#   inflating: SiamFCVideo/img/0071.jpg
#   inflating: SiamFCVideo/img/0072.jpg
#   inflating: SiamFCVideo/img/0073.jpg
#   inflating: SiamFCVideo/img/0074.jpg
#   inflating: SiamFCVideo/img/0075.jpg
#   inflating: SiamFCVideo/img/0077.jpg
#   inflating: SiamFCVideo/img/0078.jpg
#   inflating: SiamFCVideo/img/0079.jpg
#   inflating: SiamFCVideo/img/0080.jpg
#   inflating: SiamFCVideo/img/0083.jpg
#   inflating: SiamFCVideo/img/0084.jpg
#   inflating: SiamFCVideo/img/0085.jpg
#   inflating: SiamFCVideo/img/0086.jpg
#   inflating: SiamFCVideo/img/0087.jpg
#   inflating: SiamFCVideo/img/0088.jpg
#   inflating: SiamFCVideo/img/0089.jpg
#   inflating: SiamFCVideo/img/0090.jpg
#   inflating: SiamFCVideo/img/0093.jpg
#   inflating: SiamFCVideo/img/0094.jpg
#   inflating: SiamFCVideo/img/0095.jpg
#   inflating: SiamFCVideo/img/0096.jpg
#   inflating: SiamFCVideo/img/0097.jpg
#   inflating: SiamFCVideo/img/0098.jpg
#   inflating: SiamFCVideo/img/0099.jpg
#   inflating: SiamFCVideo/img/0100.jpg
#   inflating: SiamFCVideo/img/0101.jpg
#   inflating: SiamFCVideo/img/0102.jpg
#   inflating: SiamFCVideo/img/0106.jpg
#   inflating: SiamFCVideo/img/0107.jpg
#   inflating: SiamFCVideo/img/0111.jpg
#   inflating: SiamFCVideo/img/0112.jpg
#   inflating: SiamFCVideo/img/0115.jpg
#   inflating: SiamFCVideo/img/0116.jpg
#   inflating: SiamFCVideo/img/0117.jpg
#   inflating: SiamFCVideo/img/0118.jpg
#   inflating: SiamFCVideo/img/0120.jpg
#   inflating: SiamFCVideo/img/0122.jpg
#   inflating: SiamFCVideo/img/0123.jpg
#   inflating: SiamFCVideo/img/0124.jpg
#   inflating: SiamFCVideo/img/0125.jpg
#   inflating: SiamFCVideo/img/0126.jpg
#   inflating: SiamFCVideo/img/0127.jpg
#   inflating: SiamFCVideo/img/0128.jpg
#   inflating: SiamFCVideo/img/0129.jpg
#   inflating: SiamFCVideo/img/0130.jpg
#   inflating: SiamFCVideo/img/0133.jpg
#   inflating: SiamFCVideo/img/0134.jpg
#   inflating: SiamFCVideo/img/0135.jpg
#   inflating: SiamFCVideo/img/0137.jpg
#   inflating: SiamFCVideo/img/0138.jpg
#   inflating: SiamFCVideo/img/0139.jpg
#   inflating: SiamFCVideo/img/0140.jpg
#   inflating: SiamFCVideo/img/0141.jpg
#   inflating: SiamFCVideo/img/0143.jpg
#   inflating: SiamFCVideo/img/0145.jpg
#   inflating: SiamFCVideo/img/0146.jpg
#   inflating: SiamFCVideo/img/0147.jpg
#   inflating: SiamFCVideo/img/0148.jpg
#   inflating: SiamFCVideo/img/0150.jpg
#   inflating: SiamFCVideo/img/0151.jpg
#   inflating: SiamFCVideo/img/0153.jpg
#   inflating: SiamFCVideo/img/0154.jpg
#   inflating: SiamFCVideo/img/0156.jpg
#   inflating: SiamFCVideo/img/0157.jpg
#   inflating: SiamFCVideo/img/0158.jpg
#   inflating: SiamFCVideo/img/0159.jpg
#   inflating: SiamFCVideo/img/0160.jpg
#   inflating: SiamFCVideo/img/0162.jpg
#   inflating: SiamFCVideo/img/0163.jpg
#   inflating: SiamFCVideo/img/0164.jpg
#   inflating: SiamFCVideo/img/0165.jpg
#   inflating: SiamFCVideo/img/0167.jpg
#   inflating: SiamFCVideo/img/0168.jpg
#   inflating: SiamFCVideo/img/0169.jpg
#   inflating: SiamFCVideo/img/0170.jpg
#   inflating: SiamFCVideo/img/0171.jpg
#   inflating: SiamFCVideo/img/0173.jpg
#   inflating: SiamFCVideo/img/0175.jpg
#   inflating: SiamFCVideo/img/0177.jpg
#   inflating: SiamFCVideo/img/0178.jpg
#   inflating: SiamFCVideo/img/0179.jpg
#   inflating: SiamFCVideo/img/0180.jpg
#   inflating: SiamFCVideo/img/0181.jpg
#   inflating: SiamFCVideo/img/0182.jpg
#   inflating: SiamFCVideo/img/0183.jpg
#   inflating: SiamFCVideo/img/0184.jpg
#   inflating: SiamFCVideo/img/0185.jpg
#   inflating: SiamFCVideo/img/0186.jpg
#   inflating: SiamFCVideo/img/0187.jpg
#   inflating: SiamFCVideo/img/0188.jpg
#   inflating: SiamFCVideo/img/0189.jpg
#   inflating: SiamFCVideo/img/0190.jpg
#   inflating: SiamFCVideo/img/0191.jpg
#   inflating: SiamFCVideo/img/0194.jpg
#   inflating: SiamFCVideo/img/0195.jpg
#   inflating: SiamFCVideo/img/0199.jpg
#   inflating: SiamFCVideo/img/0200.jpg
#   inflating: SiamFCVideo/img/0201.jpg
#   inflating: SiamFCVideo/img/0202.jpg
#   inflating: SiamFCVideo/img/0203.jpg
#   inflating: SiamFCVideo/img/0204.jpg
#   inflating: SiamFCVideo/img/0205.jpg
#   inflating: SiamFCVideo/img/0206.jpg
#   inflating: SiamFCVideo/img/0207.jpg
#   inflating: SiamFCVideo/img/0209.jpg
#   inflating: SiamFCVideo/img/0210.jpg
#   inflating: SiamFCVideo/img/0211.jpg
#   inflating: SiamFCVideo/img/0212.jpg
#   inflating: SiamFCVideo/img/0214.jpg
#   inflating: SiamFCVideo/img/0215.jpg
#   inflating: SiamFCVideo/img/0218.jpg
#   inflating: SiamFCVideo/img/0219.jpg
#   inflating: SiamFCVideo/img/0220.jpg
#   inflating: SiamFCVideo/img/0221.jpg
#   inflating: SiamFCVideo/img/0222.jpg
#   inflating: SiamFCVideo/img/0223.jpg
#   inflating: SiamFCVideo/img/0224.jpg
#   inflating: SiamFCVideo/img/0230.jpg
#   inflating: SiamFCVideo/img/0231.jpg
#   inflating: SiamFCVideo/img/0232.jpg
#   inflating: SiamFCVideo/img/0233.jpg
#   inflating: SiamFCVideo/img/0234.jpg
#   inflating: SiamFCVideo/img/0236.jpg
#   inflating: SiamFCVideo/img/0238.jpg
#   inflating: SiamFCVideo/img/0239.jpg
#   inflating: SiamFCVideo/img/0240.jpg
#   inflating: SiamFCVideo/img/0241.jpg
#   inflating: SiamFCVideo/img/0242.jpg
#   inflating: SiamFCVideo/img/0243.jpg
#   inflating: SiamFCVideo/img/0245.jpg
#   inflating: SiamFCVideo/img/0247.jpg
#   inflating: SiamFCVideo/img/0248.jpg
#   inflating: SiamFCVideo/img/0249.jpg
#   inflating: SiamFCVideo/img/0250.jpg
#   inflating: SiamFCVideo/img/0251.jpg
#   inflating: SiamFCVideo/img/0253.jpg
#   inflating: SiamFCVideo/img/0254.jpg
#   inflating: SiamFCVideo/img/0255.jpg
#   inflating: SiamFCVideo/img/0256.jpg
#   inflating: SiamFCVideo/img/0257.jpg
#   inflating: SiamFCVideo/img/0260.jpg
#   inflating: SiamFCVideo/img/0266.jpg
#   inflating: SiamFCVideo/img/0267.jpg
#   inflating: SiamFCVideo/img/0268.jpg
#   inflating: SiamFCVideo/img/0269.jpg
#   inflating: SiamFCVideo/img/0270.jpg
#   inflating: SiamFCVideo/img/0272.jpg
#   inflating: SiamFCVideo/img/0273.jpg
#   inflating: SiamFCVideo/img/0274.jpg
#   inflating: SiamFCVideo/img/0276.jpg
#   inflating: SiamFCVideo/img/0278.jpg
#   inflating: SiamFCVideo/img/0279.jpg
#   inflating: SiamFCVideo/img/0280.jpg
#   inflating: SiamFCVideo/img/0281.jpg
#   inflating: SiamFCVideo/img/0283.jpg
#   inflating: SiamFCVideo/img/0284.jpg
#   inflating: SiamFCVideo/img/0288.jpg
#   inflating: SiamFCVideo/img/0291.jpg
#   inflating: SiamFCVideo/img/0292.jpg
#   inflating: SiamFCVideo/img/0293.jpg
#   inflating: SiamFCVideo/img/0294.jpg
#   inflating: SiamFCVideo/img/0295.jpg
#   inflating: SiamFCVideo/img/0296.jpg
#   inflating: SiamFCVideo/img/0297.jpg
#   inflating: SiamFCVideo/img/0302.jpg
#   inflating: SiamFCVideo/img/0305.jpg
#   inflating: SiamFCVideo/img/0306.jpg
#   inflating: SiamFCVideo/img/0307.jpg
#   inflating: SiamFCVideo/img/0308.jpg
#   inflating: SiamFCVideo/img/0309.jpg
#   inflating: SiamFCVideo/img/0310.jpg
#   inflating: SiamFCVideo/img/0311.jpg
#   inflating: SiamFCVideo/img/0312.jpg
#   inflating: SiamFCVideo/img/0313.jpg
#   inflating: SiamFCVideo/img/0314.jpg
#   inflating: SiamFCVideo/img/0315.jpg
#   inflating: SiamFCVideo/img/0317.jpg
#   inflating: SiamFCVideo/img/0318.jpg
#   inflating: SiamFCVideo/img/0319.jpg
#   inflating: SiamFCVideo/img/0321.jpg
#   inflating: SiamFCVideo/img/0322.jpg
#   inflating: SiamFCVideo/img/0325.jpg
#   inflating: SiamFCVideo/img/0326.jpg
#   inflating: SiamFCVideo/img/0327.jpg
#   inflating: SiamFCVideo/img/0328.jpg
#   inflating: SiamFCVideo/img/0331.jpg
#   inflating: SiamFCVideo/img/0332.jpg
#   inflating: SiamFCVideo/img/0337.jpg
#   inflating: SiamFCVideo/img/0338.jpg
#   inflating: SiamFCVideo/img/0339.jpg
#   inflating: SiamFCVideo/img/0340.jpg
#   inflating: SiamFCVideo/img/0341.jpg
#   inflating: SiamFCVideo/img/0342.jpg
#   inflating: SiamFCVideo/img/0344.jpg
#   inflating: SiamFCVideo/img/0346.jpg
#   inflating: SiamFCVideo/img/0348.jpg
#   inflating: SiamFCVideo/img/0349.jpg
#   inflating: SiamFCVideo/img/0351.jpg
#   inflating: SiamFCVideo/img/0352.jpg
#   inflating: SiamFCVideo/img/0353.jpg
#   inflating: SiamFCVideo/img/0354.jpg
#   inflating: SiamFCVideo/img/0355.jpg
#   inflating: SiamFCVideo/img/0356.jpg
#   inflating: SiamFCVideo/img/0357.jpg
#   inflating: SiamFCVideo/img/0358.jpg
#   inflating: SiamFCVideo/img/0359.jpg
#   inflating: SiamFCVideo/img/0360.jpg
#   inflating: SiamFCVideo/img/0361.jpg
#   inflating: SiamFCVideo/img/0364.jpg
#   inflating: SiamFCVideo/img/0365.jpg
#   inflating: SiamFCVideo/img/0366.jpg
#   inflating: SiamFCVideo/img/0367.jpg
#   inflating: SiamFCVideo/img/0368.jpg
#   inflating: SiamFCVideo/img/0369.jpg
#   inflating: SiamFCVideo/img/0370.jpg
#   inflating: SiamFCVideo/img/0372.jpg
#   inflating: SiamFCVideo/img/0373.jpg
#   inflating: SiamFCVideo/img/0375.jpg
#   inflating: SiamFCVideo/img/0377.jpg
#   inflating: SiamFCVideo/img/0378.jpg
#   inflating: SiamFCVideo/img/0380.jpg
#   inflating: SiamFCVideo/img/0381.jpg
#   inflating: SiamFCVideo/img/0382.jpg
#   inflating: SiamFCVideo/img/0384.jpg
#   inflating: SiamFCVideo/img/0385.jpg
#   inflating: SiamFCVideo/img/0386.jpg
#   inflating: SiamFCVideo/img/0387.jpg
#   inflating: SiamFCVideo/img/0388.jpg
#   inflating: SiamFCVideo/img/0389.jpg
#   inflating: SiamFCVideo/img/0390.jpg
#   inflating: SiamFCVideo/img/0391.jpg
#   inflating: SiamFCVideo/img/0392.jpg
#   inflating: SiamFCVideo/img/0393.jpg
#   inflating: SiamFCVideo/img/0394.jpg
#   inflating: SiamFCVideo/img/0395.jpg
#   inflating: SiamFCVideo/img/0396.jpg
#   inflating: SiamFCVideo/img/0397.jpg
#   inflating: SiamFCVideo/img/0398.jpg
#   inflating: SiamFCVideo/img/0399.jpg
#   inflating: SiamFCVideo/img/0400.jpg
#   inflating: SiamFCVideo/img/0401.jpg
#   inflating: SiamFCVideo/img/0402.jpg
#   inflating: SiamFCVideo/img/0404.jpg
#   inflating: SiamFCVideo/img/0405.jpg
#   inflating: SiamFCVideo/img/0406.jpg
#   inflating: SiamFCVideo/img/0407.jpg
#   inflating: SiamFCVideo/img/0410.jpg
#   inflating: SiamFCVideo/img/0412.jpg
#   inflating: SiamFCVideo/img/0414.jpg
#   inflating: SiamFCVideo/img/0415.jpg
#   inflating: SiamFCVideo/img/0416.jpg
#   inflating: SiamFCVideo/img/0417.jpg
#   inflating: SiamFCVideo/img/0418.jpg
#   inflating: SiamFCVideo/img/0422.jpg
#   inflating: SiamFCVideo/img/0423.jpg
#   inflating: SiamFCVideo/img/0424.jpg
#   inflating: SiamFCVideo/img/0425.jpg
#   inflating: SiamFCVideo/img/0428.jpg
#   inflating: SiamFCVideo/img/0429.jpg
#   inflating: SiamFCVideo/img/0430.jpg
#   inflating: SiamFCVideo/img/0432.jpg
#   inflating: SiamFCVideo/img/0433.jpg
#   inflating: SiamFCVideo/img/0434.jpg
#   inflating: SiamFCVideo/img/0435.jpg
#   inflating: SiamFCVideo/img/0436.jpg
#   inflating: SiamFCVideo/img/0437.jpg
#   inflating: SiamFCVideo/img/0438.jpg
#   inflating: SiamFCVideo/img/0441.jpg
#   inflating: SiamFCVideo/img/0443.jpg
#   inflating: SiamFCVideo/img/0445.jpg
#   inflating: SiamFCVideo/img/0449.jpg
#   inflating: SiamFCVideo/img/0450.jpg
#   inflating: SiamFCVideo/img/0453.jpg
#   inflating: SiamFCVideo/img/0454.jpg
#   inflating: SiamFCVideo/img/0455.jpg
#   inflating: SiamFCVideo/img/0456.jpg
#   inflating: SiamFCVideo/img/0460.jpg
#   inflating: SiamFCVideo/img/0463.jpg
#   inflating: SiamFCVideo/img/0464.jpg
#   inflating: SiamFCVideo/img/0465.jpg
#   inflating: SiamFCVideo/img/0466.jpg
#   inflating: SiamFCVideo/img/0467.jpg
#   inflating: SiamFCVideo/img/0468.jpg
#   inflating: SiamFCVideo/img/0470.jpg
#   inflating: SiamFCVideo/img/0471.jpg
#   inflating: SiamFCVideo/img/0473.jpg
#   inflating: SiamFCVideo/img/0475.jpg
#   inflating: SiamFCVideo/img/0476.jpg
#   inflating: SiamFCVideo/img/0478.jpg
#   inflating: SiamFCVideo/img/0479.jpg
#   inflating: SiamFCVideo/img/0482.jpg
#   inflating: SiamFCVideo/img/0483.jpg
#   inflating: SiamFCVideo/img/0484.jpg
#   inflating: SiamFCVideo/img/0485.jpg
#   inflating: SiamFCVideo/img/0487.jpg
#   inflating: SiamFCVideo/img/0488.jpg
#   inflating: SiamFCVideo/img/0489.jpg
#   inflating: SiamFCVideo/img/0490.jpg
#   inflating: SiamFCVideo/img/0491.jpg
#   inflating: SiamFCVideo/img/0492.jpg
#   inflating: SiamFCVideo/img/0493.jpg
#   inflating: SiamFCVideo/img/0494.jpg
#   inflating: SiamFCVideo/img/0495.jpg
#   inflating: SiamFCVideo/img/0496.jpg
#   inflating: SiamFCVideo/img/0497.jpg
#   inflating: SiamFCVideo/img/0498.jpg
#   inflating: SiamFCVideo/img/0499.jpg
#   inflating: SiamFCVideo/img/0500.jpg
#   inflating: SiamFCVideo/img/0003.jpg
#   inflating: SiamFCVideo/img/0007.jpg
#   inflating: SiamFCVideo/img/0015.jpg
#   inflating: SiamFCVideo/img/0020.jpg
#   inflating: SiamFCVideo/img/0022.jpg
#   inflating: SiamFCVideo/img/0025.jpg
#   inflating: SiamFCVideo/img/0027.jpg
#   inflating: SiamFCVideo/img/0029.jpg
#   inflating: SiamFCVideo/img/0034.jpg
#   inflating: SiamFCVideo/img/0037.jpg
#   inflating: SiamFCVideo/img/0041.jpg
#   inflating: SiamFCVideo/img/0043.jpg
#   inflating: SiamFCVideo/img/0046.jpg
#   inflating: SiamFCVideo/img/0051.jpg
#   inflating: SiamFCVideo/img/0053.jpg
#   inflating: SiamFCVideo/img/0055.jpg
#   inflating: SiamFCVideo/img/0059.jpg
#   inflating: SiamFCVideo/img/0061.jpg
#   inflating: SiamFCVideo/img/0069.jpg
#   inflating: SiamFCVideo/img/0076.jpg
#   inflating: SiamFCVideo/img/0081.jpg
#   inflating: SiamFCVideo/img/0082.jpg
#   inflating: SiamFCVideo/img/0091.jpg
#   inflating: SiamFCVideo/img/0092.jpg
#   inflating: SiamFCVideo/img/0103.jpg
#   inflating: SiamFCVideo/img/0104.jpg
#   inflating: SiamFCVideo/img/0105.jpg
#   inflating: SiamFCVideo/img/0108.jpg
#   inflating: SiamFCVideo/img/0109.jpg
#   inflating: SiamFCVideo/img/0110.jpg
#   inflating: SiamFCVideo/img/0113.jpg
#   inflating: SiamFCVideo/img/0114.jpg
#   inflating: SiamFCVideo/img/0119.jpg
#   inflating: SiamFCVideo/img/0121.jpg
#   inflating: SiamFCVideo/img/0131.jpg
#   inflating: SiamFCVideo/img/0132.jpg
#   inflating: SiamFCVideo/img/0136.jpg
#   inflating: SiamFCVideo/img/0142.jpg
#   inflating: SiamFCVideo/img/0144.jpg
#   inflating: SiamFCVideo/img/0149.jpg
#   inflating: SiamFCVideo/img/0152.jpg
#   inflating: SiamFCVideo/img/0155.jpg
#   inflating: SiamFCVideo/img/0161.jpg
#   inflating: SiamFCVideo/img/0166.jpg
#   inflating: SiamFCVideo/img/0172.jpg
#   inflating: SiamFCVideo/img/0174.jpg
#   inflating: SiamFCVideo/img/0176.jpg
#   inflating: SiamFCVideo/img/0192.jpg
#   inflating: SiamFCVideo/img/0193.jpg
#   inflating: SiamFCVideo/img/0196.jpg
#   inflating: SiamFCVideo/img/0197.jpg
#   inflating: SiamFCVideo/img/0198.jpg
#   inflating: SiamFCVideo/img/0208.jpg
#   inflating: SiamFCVideo/img/0213.jpg
#   inflating: SiamFCVideo/img/0216.jpg
#   inflating: SiamFCVideo/img/0217.jpg
#   inflating: SiamFCVideo/img/0225.jpg
#   inflating: SiamFCVideo/img/0226.jpg
#   inflating: SiamFCVideo/img/0227.jpg
#   inflating: SiamFCVideo/img/0228.jpg
#   inflating: SiamFCVideo/img/0229.jpg
#   inflating: SiamFCVideo/img/0235.jpg
#   inflating: SiamFCVideo/img/0237.jpg
#   inflating: SiamFCVideo/img/0244.jpg
#   inflating: SiamFCVideo/img/0246.jpg
#   inflating: SiamFCVideo/img/0252.jpg
#   inflating: SiamFCVideo/img/0258.jpg
#   inflating: SiamFCVideo/img/0259.jpg
#   inflating: SiamFCVideo/img/0261.jpg
#   inflating: SiamFCVideo/img/0262.jpg
#   inflating: SiamFCVideo/img/0263.jpg
#   inflating: SiamFCVideo/img/0264.jpg
#   inflating: SiamFCVideo/img/0265.jpg
#   inflating: SiamFCVideo/img/0271.jpg
#   inflating: SiamFCVideo/img/0275.jpg
#   inflating: SiamFCVideo/img/0277.jpg
#   inflating: SiamFCVideo/img/0282.jpg
#   inflating: SiamFCVideo/img/0285.jpg
#   inflating: SiamFCVideo/img/0286.jpg
#   inflating: SiamFCVideo/img/0287.jpg
#   inflating: SiamFCVideo/img/0289.jpg
#   inflating: SiamFCVideo/img/0290.jpg
#   inflating: SiamFCVideo/img/0298.jpg
#   inflating: SiamFCVideo/img/0299.jpg
#   inflating: SiamFCVideo/img/0300.jpg
#   inflating: SiamFCVideo/img/0301.jpg
#   inflating: SiamFCVideo/img/0303.jpg
#   inflating: SiamFCVideo/img/0304.jpg
#   inflating: SiamFCVideo/img/0316.jpg
#   inflating: SiamFCVideo/img/0320.jpg
#   inflating: SiamFCVideo/img/0323.jpg
#   inflating: SiamFCVideo/img/0324.jpg
#   inflating: SiamFCVideo/img/0329.jpg
#   inflating: SiamFCVideo/img/0330.jpg
#   inflating: SiamFCVideo/img/0333.jpg
#   inflating: SiamFCVideo/img/0334.jpg
#   inflating: SiamFCVideo/img/0335.jpg
#   inflating: SiamFCVideo/img/0336.jpg
#   inflating: SiamFCVideo/img/0343.jpg
#   inflating: SiamFCVideo/img/0345.jpg
#   inflating: SiamFCVideo/img/0347.jpg
#   inflating: SiamFCVideo/img/0350.jpg
#   inflating: SiamFCVideo/img/0362.jpg
#   inflating: SiamFCVideo/img/0363.jpg
#   inflating: SiamFCVideo/img/0371.jpg
#   inflating: SiamFCVideo/img/0374.jpg
#   inflating: SiamFCVideo/img/0376.jpg
#   inflating: SiamFCVideo/img/0379.jpg
#   inflating: SiamFCVideo/img/0383.jpg
#   inflating: SiamFCVideo/img/0403.jpg
#   inflating: SiamFCVideo/img/0408.jpg
#   inflating: SiamFCVideo/img/0409.jpg
#   inflating: SiamFCVideo/img/0411.jpg
#   inflating: SiamFCVideo/img/0413.jpg
#   inflating: SiamFCVideo/img/0419.jpg
#   inflating: SiamFCVideo/img/0420.jpg
#   inflating: SiamFCVideo/img/0421.jpg
#   inflating: SiamFCVideo/img/0426.jpg
#   inflating: SiamFCVideo/img/0427.jpg
#   inflating: SiamFCVideo/img/0431.jpg
#   inflating: SiamFCVideo/img/0439.jpg
#   inflating: SiamFCVideo/img/0440.jpg
#   inflating: SiamFCVideo/img/0442.jpg
#   inflating: SiamFCVideo/img/0444.jpg
#   inflating: SiamFCVideo/img/0446.jpg
#   inflating: SiamFCVideo/img/0447.jpg
#   inflating: SiamFCVideo/img/0448.jpg
#   inflating: SiamFCVideo/img/0451.jpg
#   inflating: SiamFCVideo/img/0452.jpg
#   inflating: SiamFCVideo/img/0457.jpg
#   inflating: SiamFCVideo/img/0458.jpg
#   inflating: SiamFCVideo/img/0459.jpg
#   inflating: SiamFCVideo/img/0461.jpg
#   inflating: SiamFCVideo/img/0462.jpg
#   inflating: SiamFCVideo/img/0469.jpg
#   inflating: SiamFCVideo/img/0472.jpg
#   inflating: SiamFCVideo/img/0474.jpg
#   inflating: SiamFCVideo/img/0477.jpg
#   inflating: SiamFCVideo/img/0480.jpg
#   inflating: SiamFCVideo/img/0481.jpg
#   inflating: SiamFCVideo/img/0486.jpg
# Archive:  RGB-T234.zip
#    creating: RGB-T234/
#    creating: RGB-T234/rainingwaliking/
#   inflating: RGB-T234/rainingwaliking/visible.txt
#   inflating: RGB-T234/rainingwaliking/infrared.txt
#    creating: RGB-T234/rainingwaliking/infrared/
#   inflating: RGB-T234/rainingwaliking/infrared/00033i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00021i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00012i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00024i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00035i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00014i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00034i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00027i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00020i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00031i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00016i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00029i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00032i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00015i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00030i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00013i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00023i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00022i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00017i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00019i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00026i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00018i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00025i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00028i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00048i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00038i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00044i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00056i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00042i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00052i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00043i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00037i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00054i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00041i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00040i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00050i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00039i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00058i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00046i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00049i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00057i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00051i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00045i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00047i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00036i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00055i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00053i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00067i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00061i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00075i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00064i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00078i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00059i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00060i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00077i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00074i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00062i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00076i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00079i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00080i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00068i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00071i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00072i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00063i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00065i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00066i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00069i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00070i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00073i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00096i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00098i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00083i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00097i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00094i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00091i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00090i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00099i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00088i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00086i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00085i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00093i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00081i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00100i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00095i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00082i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00092i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00084i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00087i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00089i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00122i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00108i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00112i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00123i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00113i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00118i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00104i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00105i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00110i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00117i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00115i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00111i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00120i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00107i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00114i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00116i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00102i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00109i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00101i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00121i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00103i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00106i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00119i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00126i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00124i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00136i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00134i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00131i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00125i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00137i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00127i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00128i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00129i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00132i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00138i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00130i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00139i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00140i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00135i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00133i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00157i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00147i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00148i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00155i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00159i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00158i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00156i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00149i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00153i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00152i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00151i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00154i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00145i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00150i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00160i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00146i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00143i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00144i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00141i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00142i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00164i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00163i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00165i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00166i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00162i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00175i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00167i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00174i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00172i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00168i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00170i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00176i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00173i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00161i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00169i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00177i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00171i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00182i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00193i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00195i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00185i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00198i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00199i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00184i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00187i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00186i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00197i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00190i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00192i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00180i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00196i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00178i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00188i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00194i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00191i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00181i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00179i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00189i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00200i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00183i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00212i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00216i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00222i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00213i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00221i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00209i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00217i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00204i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00219i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00215i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00205i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00201i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00218i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00211i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00214i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00208i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00206i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00220i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00202i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00207i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00210i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00203i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00231i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00227i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00229i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00235i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00239i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00232i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00230i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00225i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00237i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00242i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00238i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00228i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00223i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00241i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00236i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00226i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00243i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00245i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00244i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00234i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00240i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00233i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00224i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00259i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00249i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00265i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00261i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00268i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00254i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00251i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00266i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00253i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00248i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00252i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00262i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00256i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00257i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00267i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00260i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00255i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00263i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00246i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00247i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00264i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00250i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00258i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00270i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00279i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00281i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00290i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00284i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00283i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00278i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00273i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00285i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00280i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00286i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00288i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00269i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00291i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00277i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00287i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00275i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00272i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00282i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00271i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00276i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00289i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00274i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00306i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00293i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00298i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00312i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00292i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00305i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00303i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00307i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00313i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00310i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00297i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00299i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00302i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00314i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00304i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00308i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00296i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00301i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00300i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00311i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00294i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00295i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00309i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00336i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00315i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00330i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00328i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00316i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00329i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00325i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00333i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00326i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00321i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00331i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00335i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00334i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00318i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00327i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00322i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00337i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00319i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00332i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00320i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00323i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00317i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00324i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00344i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00338i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00353i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00357i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00352i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00348i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00343i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00349i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00346i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00356i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00339i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00355i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00360i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00351i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00340i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00358i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00350i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00345i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00341i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00342i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00354i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00347i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00359i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00372i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00364i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00369i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00379i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00366i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00371i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00375i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00382i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00380i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00363i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00376i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00367i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00384i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00373i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00362i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00374i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00365i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00377i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00361i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00370i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00383i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00378i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00368i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00381i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00398i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00390i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00394i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00393i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00400i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00387i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00386i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00389i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00397i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00385i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00392i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00391i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00388i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00396i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00399i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00395i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00422i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00418i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00416i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00405i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00410i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00412i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00406i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00414i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00421i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00404i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00411i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00413i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00409i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00408i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00420i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00401i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00402i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00415i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00417i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00407i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00419i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00403i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00431i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00442i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00423i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00424i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00438i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00439i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00433i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00428i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00441i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00429i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00430i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00435i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00444i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00427i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00426i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00434i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00437i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00425i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00440i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00436i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00432i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00443i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00448i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00460i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00458i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00462i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00457i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00455i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00465i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00452i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00461i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00453i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00466i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00451i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00445i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00454i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00449i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00447i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00459i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00464i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00463i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00446i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00450i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00456i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00477i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00476i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00485i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00468i.jpg
#   inflating: RGB-T234/rainingwaliking/infrared/00488i.jpg
# ...
#   inflating: RGB-T234/rainingwaliking/visible/00753v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00755v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00756v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00743v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00746v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00744v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00742v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00769v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00767v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00759v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00773v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00776v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00778v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00772v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00780v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00760v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00771v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00775v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00763v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00764v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00770v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00774v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00779v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00768v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00762v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00761v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00777v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00766v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00765v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00785v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00784v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00799v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00788v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00782v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00800v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00791v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00793v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00798v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00786v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00792v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00781v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00783v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00790v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00801v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00794v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00787v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00789v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00795v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00796v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00797v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00802v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00813v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00812v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00806v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00804v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00814v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00816v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00820v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00803v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00811v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00815v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00821v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00808v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00805v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00819v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00807v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00817v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00809v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00818v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00810v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00828v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00838v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00823v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00829v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00825v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00840v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00827v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00831v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00834v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00824v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00839v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00835v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00830v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00833v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00822v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00836v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00837v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00841v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00826v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00832v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00844v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00857v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00842v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00852v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00848v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00847v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00846v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00849v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00843v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00859v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00858v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00856v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00845v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00851v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00860v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00853v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00854v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00855v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00850v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00861v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00877v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00863v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00874v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00867v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00878v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00883v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00864v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00872v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00873v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00868v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00876v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00875v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00882v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00870v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00865v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00880v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00881v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00862v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00871v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00866v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00879v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00869v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00898v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00904v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00901v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00887v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00897v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00894v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00902v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00905v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00892v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00899v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00896v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00890v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00889v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00886v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00900v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00884v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00903v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00895v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00888v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00891v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00893v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00885v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00912v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00918v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00910v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00915v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00926v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00919v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00914v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00924v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00922v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00909v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00911v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00921v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00913v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00927v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00908v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00917v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00923v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00906v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00916v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00907v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00925v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00920v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00944v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00939v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00945v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00938v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00933v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00934v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00929v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00932v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00931v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00947v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00948v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00936v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00946v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00949v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00937v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00943v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00930v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00941v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00942v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00928v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00940v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00935v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00966v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00958v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00963v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00970v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00964v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00961v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00954v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00962v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00967v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00950v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00953v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00971v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00952v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00965v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00960v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00956v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00951v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00959v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00955v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00957v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00968v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00969v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00979v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00972v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00980v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00976v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00988v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00977v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00978v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00993v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00975v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00982v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00973v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00985v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00987v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00986v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00981v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00974v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00990v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00989v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00992v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00984v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00991v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00983v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00996v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00999v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01003v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01007v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01008v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01010v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01005v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01006v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01000v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01004v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00995v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01002v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01001v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00997v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00998v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01011v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00994v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/01009v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00007v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00002v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00001v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00013v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00016v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00010v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00011v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00005v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00008v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00004v.jpg
#   inflating: RGB-T234/rainingwaliking/visible/00009v.jpg

# %%
# check if successfully uploading the files
# should show: Config.py, SiamFCModel.pth, SiamFCVideo, SiamFCVideo.zip, RGB-T234, RGB-T234.zip, SiamNet.py
# !ls
# Out:
# Config.py		 __pycache__	   SiamFCVideo.zip
# CSE527-22S-HW5-P1.ipynb  RGB-T234	   SiamNet.py
# CSE527-22S-HW5-P2.ipynb  RGB-T234.zip	   Tracking_Res.txt
# data_uav.tar.gz		 SiamFCMModel.pth  Tracking_Result.txt
# faster-rcnn.pytorch	 SiamFCVideo

# %% [markdown]
# # Problem 1: SiamFC Tracking Algorithm
#
# (35 points) **Some important instructions:**
#
#
# *   After finishing preparing the data, it is better to check each of them;
# *   The network of SiamFC is defined in *SiamNet.py*, and you can check it to get familar with the architecture of SiamFC;
# *   There are some parameters defined in the Config.py, and you need to know some of them for coordinate transformation;
#
#
# **NOTE 1: before starting the implementation try to read what existing methods are trying to acheive, so you know how to use them.**
#
# **NOTE 2: before running the code, please change runtime type to GPU**
#
# **NOTE 3: There are many available resources about SiamFC online, and you should finish this assignment on your own. Do NOT copy-and-paste!!!**

# %%
# Code for SiamFC tracking algorithm
import torchvision.transforms.functional as F
import cv2
from torch.autograd import Variable
import torch
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import glob
from Config import *
from IPython.display import clear_output
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def load_sequence(seq_path):
    """
    load sequences;
    sequences should be in OTB format, or you can custom this function by yourself
    """
    # given the sequence path, you need to load sequence information, including
    # img_list: a list, each element of which is the path for an image
    # target_position: an array, the center position of the target [center_y, center_x]
    # target_sz: an array, the height and width of the target [h, w]
    # NOTE: the sequence folder contains a sub-folder that contains all image files, 
    # and a 'groundtruth_rect.txt' that contains the initial groundtruth of the target in format (top_left_x, top_left_y, width, height)

    ##########--WRITE YOUR CODE HERE--##########

    imgpath = os.path.join(seq_path,'img')
    groundtruthfile = os.path.join(seq_path, 'groundtruth_rect.txt')
    
    img_list = []
    img_list = [imgfile for imgfile in glob.glob(os.path.join(imgpath, "*.jpg"))]
    img_list.sort()
    
    groundtruth = open(groundtruthfile, 'r')
    reader = groundtruth.readline()
    region = [float(i) for i in reader.strip().split(",")]
    top_left_x, top_left_y = region[0], region[1]
    w, h = region[2], region[3]
    cx = top_left_x + w/2
    cy = top_left_y + h/2
    
    target_position= np.array([cy, cx], dtype = np.double)
    target_sz = np.array([h,w], dtype = np.double)

    ##########-------END OF CODE-------########## 

    return img_list, target_position, target_sz


def visualize_tracking_result(img, bbox, fig_n):
    """
    visualize tracking result
    """
    fig = plt.figure(fig_n)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    r = patches.Rectangle((bbox[0], bbox[1]), bbox[2], bbox[3], linewidth = 3, edgecolor = "#00ff00", zorder = 1, fill = False)
    ax.imshow(img)
    ax.add_patch(r)
    plt.ion()
    plt.show()
    plt.pause(0.00001)
    plt.clf()


def get_subwindow_tracking(im, pos, model_sz, original_sz, avg_chans):
    """
    extract image crop 
    """
    # im: input image
    # pos: [center_y, center_x] of the position around which image has to be cropped
    # model_sz: size to which the cropped portion has to be rescaled before return
    # original_sz: size of the patch to be cropped from the original image
    # avg_channels: a 3 sized array indicating avg intensities of pixels in RGB. This
    # color is used for padding areas 

    if original_sz is None:
        original_sz = model_sz

    sz = original_sz
    im_sz = im.shape
    # make sure the size is not too small
    assert (im_sz[0] > 2) & (im_sz[1] > 2), "The size of image is too small!"
    c = (sz+1) / 2

    # check out-of-bounds coordinates, and set them to black
    context_xmin = round(pos[1] - c)       # floor(pos(2) - sz(2) / 2);
    context_xmax = context_xmin + sz - 1
    context_ymin = round(pos[0] - c)       # floor(pos(1) - sz(1) / 2);
    context_ymax = context_ymin + sz - 1

    # compute padding
    left_pad = max(0, 1-context_xmin)       # in python, index starts from 0
    top_pad = max(0, 1-context_ymin)
    right_pad = max(0, context_xmax - im_sz[1])
    bottom_pad = max(0, context_ymax - im_sz[0])

    context_xmin = context_xmin + left_pad
    context_xmax = context_xmax + left_pad
    context_ymin = context_ymin + top_pad
    context_ymax = context_ymax + top_pad

    im_R = im[:, :, 0]
    im_G = im[:, :, 1]
    im_B = im[:, :, 2]

    # padding
    if (top_pad !=0) | (bottom_pad !=0) | (left_pad !=0) | (right_pad !=0):
        im_R = np.pad(im_R, ((int(top_pad), int(bottom_pad)), (int(left_pad), int(right_pad))), 'constant', constant_values = avg_chans[0])
        im_G = np.pad(im_G, ((int(top_pad), int(bottom_pad)), (int(left_pad), int(right_pad))), 'constant', constant_values = avg_chans[1])
        im_B = np.pad(im_B, ((int(top_pad), int(bottom_pad)), (int(left_pad), int(right_pad))), 'constant', constant_values = avg_chans[2])

        im = np.concatenate([im_R[...,np.newaxis], im_G[...,np.newaxis], im_B[...,np.newaxis]], axis=2, dtype=np.double)

    im_patch_original = im[int(context_ymin)-1:int(context_ymax), int(context_xmin)-1:int(context_xmax), :]

    # resize to the 'model_sz'
    if model_sz != original_sz:
        im_patch = cv2.resize(im_patch_original, (int(model_sz), int(model_sz)), interpolation = cv2.INTER_CUBIC)
    else:
        im_patch = im_patch_original

    return im_patch


def make_scale_pyramid(im, target_position, in_side_scaled, out_side, avg_chans, p):
    """
    extract multi-scale image crops
    Used for extracting different scales of area of interest from the search image
    """
    # im: image
    # target_position: center of the area of interest
    # in_side_scaled: The lengths of the sides of 'area of interest' squares at differnt scales   
    # out_side: The resolution (of a side) of each pyramid level 
    # avg_chans: a 3 sized array indicating avg intensities of pixels in RGB. This
    # color is used for padding areas 
    # p: config

    in_side_scaled = np.round(in_side_scaled)
    pyramid = np.zeros((out_side, out_side, 3, p.num_scale), dtype = np.double)
    max_target_side = in_side_scaled[in_side_scaled.size-1]
    min_target_side = in_side_scaled[0]
    beta = out_side / min_target_side
    # size_in_search_area = beta * size_in_image
    # e.g. out_side = beta * min_target_side
    search_side = round(beta * max_target_side)

    search_region = get_subwindow_tracking(im, target_position, search_side, max_target_side, avg_chans)

    assert (round(beta * min_target_side) == out_side), "Error!"

    # extract multiple pyramid patches using get_subwindow_tracking() function;
    # you should use a loop to do this;
    # the number of scales is indicated by p.num_scale;
    # the scale information is stored in in_side_scaled[];
    # the obtained pryamid is represented in variable 'pyramid';
    
    ##########--WRITE YOUR CODE HERE--##########

    for s in range(p.num_scale):
        target_side = round(beta * in_side_scaled[s])
        search_target_position = np.array([1 + search_side/2, 1 + search_side/2], dtype = np.double)
        pyramid[:, :, :, s] = get_subwindow_tracking(search_region, search_target_position, out_side,
                                                   target_side, avg_chans)
                                  
    ##########-------END OF CODE-------##########  
    return pyramid


def tracker_eval(net, s_x, z_features, x_features, target_position, window, p):
    """
    do evaluation (i.e., a forward pass for search region)
    
    This method takes in the feature maps of search and the target image and finds
    the target position and scale. 
    """
    # net: model
    # s_x: size of the area of interest patch cropped from original input search image
    # z_features: siamFC features of target image
    # x_features: siamFC features of search image
    # target_position: center of the area of interest from original input image
    # window: a 2D array to adapt the response map for better tracking
    # p: config
    
    # compute scores search regions of different scales
    scores = net.xcorr(z_features, x_features)
    scores = scores.to("cpu")

    response_maps = scores.squeeze().permute(1, 2, 0).data.numpy()
    # for this one, the opencv resize function works fine
    response_maps_up = cv2.resize(response_maps, (response_maps.shape[0]*p.response_UP, response_maps.shape[0]*p.response_UP), interpolation=cv2.INTER_CUBIC)

    # choose the scale whose response map has the highest peak
    if p.num_scale > 1:
        current_scale_id =np.ceil(p.num_scale/2)
        best_scale = current_scale_id
        best_peak = float("-inf")
        for s in range(p.num_scale):
            this_response = response_maps_up[:, :, s]
            # penalize change of scale
            if s != current_scale_id:
                this_response = this_response * p.scale_penalty
            this_peak = np.max(this_response)
            if this_peak > best_peak:
                best_peak = this_peak
                best_scale = s
        response_map = response_maps_up[:, :, int(best_scale)]
    else:
        response_map = response_maps_up
        best_scale = 1
    # make the response map sum to 1
    response_map = response_map - np.min(response_map)
    response_map = response_map / sum(sum(response_map))

    # apply windowing
    response_map = (1 - p.w_influence) * response_map + p.w_influence * window
    p_corr = np.asarray(np.unravel_index(np.argmax(response_map), np.shape(response_map)))

    # avoid empty
    if p_corr[0] is None:
        p_corr[0] = np.ceil(p.score_size/2)
    if p_corr[1] is None:
        p_corr[1] = np.ceil(p.score_size/2)

    # Convert to crop-relative coordinates p_corr to frame coordinates
    # the frame coordinates are represented using new_target_position (it is an array)
    # Hint: You may do this part by computing:
    # 1. displacement from the center in instance final representation
    # 2. displacement in instance input
    # 3. displacement in instance original crop (in frame coordinates)
    # 4. new target position within frame in frame coordinates
    # (You need to use some parameters in Config for this part)


    ##########--WRITE YOUR CODE HERE--##########

    disp_instance_final = p_corr - np.ceil(p.score_size * p.response_UP / 2)
    disp_instance_input = disp_instance_final * p.stride / p.response_UP
    disp_instance_frame = disp_instance_input * s_x / p.instance_size
    new_target_position = target_position + disp_instance_frame

    ##########-------END OF CODE-------##########

    return new_target_position, best_scale


def run_tracker(img_list, target_position, target_size, save_to_file='./Tracking_Res.txt'):

    # get the default parameters
    p = Config()

    # load model
    net = torch.load('./SiamFCMModel.pth')
    net = net.to(device)

    # evaluation mode
    net.eval()

    # first frame
    img_uint8 = cv2.imread(img_list[0])
    img_uint8 = cv2.cvtColor(img_uint8, cv2.COLOR_BGR2RGB)
    img_double = np.double(img_uint8)  # uint8 to float

    # compute avg for padding
    avg_chans = np.mean(img_double, axis=(0, 1))


    # computing variables for later scaling and cropping operations
    # Try to understand these to get better understanding of how we pull target
    # image patch
    wc_z = target_size[1] + p.context_amount * sum(target_size)
    hc_z = target_size[0] + p.context_amount * sum(target_size)
    s_z = np.sqrt(wc_z * hc_z)
    scale_z = p.examplar_size / s_z

    # crop examplar z in the first frame
    z_crop = get_subwindow_tracking(img_double, target_position, p.examplar_size, round(s_z), avg_chans)
    z_crop = np.uint8(z_crop)  # you need to convert it to uint8
    # convert image to tensor
    z_crop_tensor = 255.0 * F.to_tensor(z_crop).unsqueeze(0)


    # computing variables to pull appropriately sized "area of interest"s from search image
    d_search = (p.instance_size - p.examplar_size) / 2
    pad = d_search / scale_z
    s_x = s_z + 2 * pad
    # arbitrary scale saturation
    min_s_x = p.scale_min * s_x
    max_s_x = p.scale_max * s_x

    # generate cosine window
    if p.windowing == 'cosine':
        window = np.outer(np.hanning(p.score_size * p.response_UP), np.hanning(p.score_size * p.response_UP))
    elif p.windowing == 'uniform':
        window = np.ones((p.score_size * p.response_UP, p.score_size * p.response_UP))
    window = window / sum(sum(window))

    # pyramid scale search
    scales = p.scale_step ** np.linspace(-np.ceil(p.num_scale / 2), np.ceil(p.num_scale / 2), p.num_scale)
    # extract feature for examplar z
    z_features = net.feat_extraction(Variable(z_crop_tensor).to(device))
    z_features = z_features.repeat(p.num_scale, 1, 1, 1)

    # do tracking
    bboxes = np.zeros((len(img_list), 4), dtype=np.double)  # save tracking result
    for i in tqdm(range(0, len(img_list)), desc="Tracking all frames in the sequence"):
        # print('processing frame %d ...' %(i+1))
        if i > 0:
            # do detection
            # currently, we only consider RGB images for tracking
            img_uint8 = cv2.imread(img_list[i])
            img_uint8 = cv2.cvtColor(img_uint8, cv2.COLOR_BGR2RGB)
            img_double = np.double(img_uint8)  # uint8 to float

            scaled_instance = s_x * scales
            scaled_target = np.zeros((2, scales.size), dtype=np.double)
            scaled_target[0, :] = target_size[0] * scales
            scaled_target[1, :] = target_size[1] * scales

            # extract scaled crops for search region x at previous target position
            x_crops = make_scale_pyramid(img_double, target_position, scaled_instance, p.instance_size, avg_chans, p)

            # get features of search regions
            x_crops_tensor = torch.FloatTensor(x_crops.shape[3], x_crops.shape[2], x_crops.shape[1], x_crops.shape[0])
            # response_map = SiameseNet.get_response_map(z_features, x_crops)
            for k in range(x_crops.shape[3]):
                tmp_x_crop = x_crops[:, :, :, k]
                tmp_x_crop = np.uint8(tmp_x_crop)
                # numpy array to tensor
                x_crops_tensor[k, :, :, :] = 255.0 * F.to_tensor(tmp_x_crop).unsqueeze(0)

            # get features of search regions
            # the input to the network is x_crop_tensors;
            # the feature of search regions is represented using 'x_features'

            ##########--WRITE YOUR CODE HERE--##########

            x_features = net.feat_extraction(Variable(x_crops_tensor).to(device))

            ##########-------END OF CODE-------##########


            # evaluate the offline-trained network for exemplar x features
            target_position, new_scale = tracker_eval(net, round(s_x), z_features, x_features, target_position, window,
                                                      p)

            # scale damping and saturation
            s_x = max(min_s_x, min(max_s_x, (1 - p.scale_LR) * s_x + p.scale_LR * scaled_instance[int(new_scale)]))
            target_size = (1 - p.scale_LR) * target_size + p.scale_LR * np.array(
                [scaled_target[0, int(new_scale)], scaled_target[1, int(new_scale)]])

        rect_position = np.array(
            [target_position[1] - target_size[1] / 2, target_position[0] - target_size[0] / 2, target_size[1],
             target_size[0]])

        # visualize the tracking results
        # comment for not visualizing
        if i % 50 == 0:
            visualize_tracking_result(img_uint8, rect_position, 1)

        # output bbox in the original frame coordinates
        o_target_position = target_position
        o_target_size = target_size
        bboxes[i, :] = np.array(
            [o_target_position[1] - o_target_size[1] / 2, o_target_position[0] - o_target_size[0] / 2, o_target_size[1],
             o_target_size[0]])
    # save tracking results
    np.savetxt(save_to_file, bboxes, fmt='%.3f')
    return bboxes


if __name__ == "__main__":
  
    # load sequence
    img_list, target_position, target_size = load_sequence('./SiamFCVideo')

    # run the tracker for given sequence and starting bounding box
    results = run_tracker(img_list, target_position, target_size, save_to_file='./Tracking_Result.txt')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **After finishing the required parts and successfully running the code, please submit your code and the obtained tracking results in Tracking_Res.txt.**

# %% [markdown]
# # 2. RGB-T Tracking
#
# (15 points) In this problem, we will explore how information from visual spectrum and infrared spectrum can complement each other for tracking.
# You are given a video sequence from the [RGB-T234 dataset](https://arxiv.org/abs/1805.08982): [RGB-T234/rainingwalking](https://drive.google.com/file/d/1LweAwT4hikySCIjtlsEi3BS0jfoU9iNn/view).
#
# It can be found in the directory:
# ```
# project root
# └───RGB-T234
# │   │
# │   └───rainingwalking
# │       │   visible.txt
# │       │   infrared.txt
# │       └───visible
# │       │      |  00123v.jpg
# │       │      |  00124v.jpg
# │       │      ...
# |       |
# │       └───infrared
# │       │      |  00123i.jpg
# │       │      |  00124i.jpg
# │       │      ...
#
# ```
#
#
# In 2.1, lets run the tracker without using the thermal channel. Here we reuse above problem 1's implementation. I.e., after loading the above sequences we just pass the RGB image sequence and the bounding box info to run_tracker() method. Additionally, we find the 'success rate' of this tracking using available ground truth

# %% [markdown]
# ## 2.1 Perform tracking on a challenging video sequence and evaluate its performance
#
#
#
# (5 points) 1. Complete the load_sequence method to read the visible frames and infrared frames. Also, read the ground truth bounding box for each sequence from the "Infrared.txt" (just like you read the problem 1's groundtruth_rect.txt ).
# Note: We will be loading both RGB and Thermal video sequences. But in 2.1 we will only utilize the RGB image sequence.
#
# (0 point) 2. Once you complete the above method, you will be able to run the tracker on the extracted RGB video sequence. To evaluate how the tracker is perfroming we are going to compute "Success Rate" metric by comparing its results to ground truth boxes.
#   "Success Rate" is defined as:
#     ratio of successfully tracked frames in total frames. A frame is considered "tracked" if Interserction-Over-Union between predicted and actual bounding boxes is over a partivcular threshold (0.3 in our case)

# %%
def load_sequence(seq_path):
    """
    load sequences;
    sequences should be in OTB format, or you can custom this function by yourself

    NOTE: target_position, target_sz are derived from first bbox info from Infrared.txt
     
    """
    # given the sequence path, you need to load sequence information, including
    # rgb_img_list: a list, each element of which is the path for an image from visible spectrum
    # t_img_list: a list, each element of which is the path for an image from thermal spectrum
    # target_position: an array, the center position of the target [center_y, center_x]
    # target_sz: an array, the height and width of the target [h, w]
    # gt: an array, of bounding box informations for each frame of the video sequence in format [(top_left_x, top_left_y, width, height), ...]
    # NOTE: the sequence folder contains a two sub-folders (visible and infrared) that contains all image files, 
    # and a 'infrared.txt' that contains the initial groundtruth of the target in format (top_left_x, top_left_y, width, height)

    ##########--WRITE YOUR CODE HERE--##########

    rgb_img_list = sorted([seq_path + '/visible/' + p for p in os.listdir(seq_path + '/visible') if os.path.splitext(p)[1] == '.jpg'])
    t_img_list = sorted([seq_path + '/infrared/' + p for p in os.listdir(seq_path + '/infrared') if os.path.splitext(p)[1] == '.jpg'])

    imgpath = os.path.join(seq_path,'img')
    groundtruthfile = os.path.join(seq_path, 'infrared.txt')

    groundtruth = open(groundtruthfile, 'r')
    reader = groundtruth.readline()
    region = [float(i) for i in reader.strip().split(",")]
    top_left_x, top_left_y = region[0], region[1]
    w, h = region[2], region[3]
    cx = top_left_x + w/2
    cy = top_left_y + h/2
    
    target_sz = np.array([h,w], dtype = np.double)
    target_position= np.array([cy, cx], dtype = np.double)
    gt = np.loadtxt(groundtruthfile, delimiter=',')

    ##########-------END OF CODE-------##########
    return rgb_img_list, t_img_list, target_position, target_sz, gt #CODE_CHANGE


def evaluate_success_rate(tracker_result, ground_truth, threshold=0.3):
    """
    Success rate metric 
    """
    # tracker_result: an array of tracked object's bbox info
    # ground_truth: an array of tracked object's ground truth bbox info
    # threshold: a bbox is considered 'suscessfully tracking' if its iou w/ 
    # groundtruth is higher than this threshold  

    def iou(bbox1, bbox2):
        l1, l2 = bbox1[1], bbox2[1]
        r1, r2 = bbox1[1]+bbox1[3], bbox2[1]+bbox2[3]
        u1, u2 = bbox1[0], bbox2[0]
        b1, b2 = bbox1[0]+bbox1[2], bbox2[0]+bbox2[2]
        # compute the Intersection Rectangle's left, right, up, bottom positions 
        l, r, u, b = max(l1, l2), min(r1, r2), max(u1, u2), min(b1, b2)
        h, w = max(0, b-u), max(0, r-l)
        # compute iou
        return h*w/( bbox1[3]*bbox1[2] + bbox2[3]*bbox2[2] - h*w )

    total_frames = len(tracker_result)
    success_frames = 0
    for i in range(total_frames):
        _iou = iou(tracker_result[i], ground_truth[i])
        success_frames = success_frames + (_iou>threshold)
    return success_frames/total_frames

if __name__ == "__main__":
  
    # load sequence
    img_list, _, target_position, target_size, gt = load_sequence('RGB-T234/rainingwaliking')
    img_list, _, target_position, target_size, gt = img_list, _, target_position, target_size, gt
    # run tracker
    results = run_tracker(img_list, target_position, target_size)
    # find average IOU of the tracking result
    print("Success Rate of the tracker on this sequence: ", evaluate_success_rate(results, gt))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##2.2 Using Thermal images to improve the performance
#
# (10 points) In the above problem we have tried to track the man walking with an umberlla.
# In this video [RGB-T234/rainingwalking](https://drive.google.com/file/d/1LweAwT4hikySCIjtlsEi3BS0jfoU9iNn/view), although we humans are able to see him and track him, the SiamFC tracker was not able to do that(given its success rate in above section is very less (<30%)). We could solve this by designing a model that is sensitive to even such inadequate visual cues. But this is a problem that needs carefull design.
#
# So, another way to fix this is by gathering more information (rather than trying to understand limited data). We can capture the environment in infrared spectrum and perceive how different objects radiate heat. This extra data can be read as a new channel alongside RGB channels in each image and can potentially improve our tracking.
#
#
# In the below code, we will use a second siamese extraction branch to extract features from thermal images and fuse them with the features from RGB images. This fusion helps encode both visual and thermal cues into the feature maps and thus lead to more accurate/sensitive response map.
#
# You can expect a success rate around 80% from this implementation.

# %%
def fuse_features(feat1_tensor, feat2_tensor):
    "fuse the network features"
    # feat1_tensor: feature of RGB channel image
    # feat2_tensor: feature of Thermal channel image

    # since you use the same network on similarly shaped input images, 
    # the features of RGB and T images will have same shape
    assert feat1_tensor.shape==feat2_tensor.shape

    
    # You can experiment with multiple ways of feature fusion and 
    # submit with whatever approch worked better
    ##########--WRITE YOUR CODE HERE--##########

    torch.cat((feat1_tensor, feat2_tensor))

    ##########-------END OF CODE-------##########


if __name__ == "__main__":

    # get the default parameters
    p = Config()

    # load model
    net = torch.load('./SiamFCMModel.pth')
    net = net.to(device)

    # evaluation mode
    net.eval()

    # load sequences
    rgb_img_list, t_img_list, target_position, target_size, gt = load_sequence('/gdrive/MyDrive/Wang_Hong_113263916_hw/Wang_Hong_113263916_hw5/RGB-T234/rainingwaliking')

    # first frame (Visual + Thermal)
    rgb_img_uint8 = cv2.imread(rgb_img_list[0])
    rgb_img_uint8 = cv2.cvtColor(rgb_img_uint8, cv2.COLOR_BGR2RGB)
    rgb_img_double = np.double(rgb_img_uint8)  # uint8 to float

    t_img_uint8 = cv2.imread(t_img_list[0])
    t_img_double = np.double(t_img_uint8)

    # compute avg for padding
    rgb_avg_chans = np.mean(rgb_img_double, axis=(0, 1))
    t_avg_chans = np.mean(t_img_double, axis=(0, 1))

    wc_z = target_size[1] + p.context_amount * sum(target_size)
    hc_z = target_size[0] + p.context_amount * sum(target_size)
    s_z = np.sqrt(wc_z * hc_z)
    scale_z = p.examplar_size / s_z

    # crop examplar z in the first frame
    rgb_z_crop = get_subwindow_tracking(rgb_img_double, target_position, p.examplar_size, round(s_z), rgb_avg_chans)
    rgb_z_crop = np.uint8(rgb_z_crop)  # you need to convert it to uint8
    # convert image to tensor
    rgb_z_crop_tensor = 255.0 * F.to_tensor(rgb_z_crop).unsqueeze(0)
    
    t_z_crop = get_subwindow_tracking(t_img_double, target_position, p.examplar_size, round(s_z), t_avg_chans)
    t_z_crop = np.uint8(t_z_crop)
    t_z_crop_tensor = 255.0 * F.to_tensor(t_z_crop).unsqueeze(0)
    
    # p.instance_size = 400
    d_search = (p.instance_size - p.examplar_size) / 2
    pad = d_search / scale_z
    s_x = s_z + 2 * pad
    # arbitrary scale saturation
    min_s_x = p.scale_min * s_x
    max_s_x = p.scale_max * s_x

    # generate cosine window
    if p.windowing == 'cosine':
        window = np.outer(np.hanning(p.score_size * p.response_UP), np.hanning(p.score_size * p.response_UP))
    elif p.windowing == 'uniform':
        window = np.ones((p.score_size * p.response_UP, p.score_size * p.response_UP))
    window = window / sum(sum(window))

    # pyramid scale search
    scales = p.scale_step ** np.linspace(-np.ceil(p.num_scale / 2), np.ceil(p.num_scale / 2), p.num_scale)
    # extract feature for examplar z
    rgb_z_features = net.feat_extraction(Variable(rgb_z_crop_tensor).to(device))
    t_z_features = net.feat_extraction(Variable(t_z_crop_tensor).to(device))
    z_features = fuse_features(rgb_z_features, t_z_features)
    z_features = z_features.repeat(p.num_scale, 1, 1, 1)

    # do tracking
    bboxes = np.zeros((len(rgb_img_list), 4), dtype=np.double)  # save tracking result
    for i in tqdm(range(0, len(rgb_img_list)), desc="Tracking all frames in the sequence"):
        # print('processing frame %d (%s) ...' %(i+1, rgb_img_list[i]))
        if i > 0:
            # do detection
            # currently, we only consider RGB images for tracking
            rgb_img_uint8 = cv2.imread(rgb_img_list[i])
            t_img_uint8 = cv2.imread(t_img_list[i])
            rgb_img_uint8 = cv2.cvtColor(rgb_img_uint8, cv2.COLOR_BGR2RGB)
            rgb_img_double = np.double(rgb_img_uint8)  # uint8 to float
            t_img_double = np.double(t_img_uint8)

            scaled_instance = s_x * scales
            scaled_target = np.zeros((2, scales.size), dtype=np.double)
            scaled_target[0, :] = target_size[0] * scales
            scaled_target[1, :] = target_size[1] * scales

            # extract scaled crops for search region x at previous target position
            rgb_x_crops = make_scale_pyramid(rgb_img_double, target_position, scaled_instance, p.instance_size, rgb_avg_chans, p)
            # repeat the above same for current thermal frame
            t_x_crops = make_scale_pyramid(t_img_double, target_position, scaled_instance, p.instance_size, t_avg_chans, p)

            # get features of search regions
            rgb_x_crops_tensor = torch.FloatTensor(rgb_x_crops.shape[3], rgb_x_crops.shape[2], rgb_x_crops.shape[1], rgb_x_crops.shape[0])
            t_x_crops_tensor = torch.FloatTensor(rgb_x_crops.shape[3], rgb_x_crops.shape[2], rgb_x_crops.shape[1], rgb_x_crops.shape[0])

            for k in range(rgb_x_crops.shape[3]):
                tmp_x_crop = np.uint8(rgb_x_crops[:, :, :, k])
                # numpy array to tensor
                rgb_x_crops_tensor[k, :, :, :] = 255.0 * F.to_tensor(tmp_x_crop).unsqueeze(0)
                # repeat for t frame
                tmp_x_crop = np.uint8(t_x_crops[:, :, :, k]) 
                t_x_crops_tensor[k, :, :, :] = 255.0 * F.to_tensor(tmp_x_crop).unsqueeze(0)


            # get features of search regions;
            # the input to the network branches are rgb_x_crop_tensors and t_x_crops_tensor;
            # the feature of search regions is represented using 'x_features'
            # use the fuse_features() method that you have implemented to fuse the features output by network branches
            # NOTE: For simplicity you can use the same siamese network to extract features of thrermal channels 
            ##########--WRITE YOUR CODE HERE--##########

            x_features = fuse_features(rgb_x_crop_tensors, t_x_crops_tensor)



            ##########-------END OF CODE-------##########

            # evaluate the offline-trained network for exemplar x features
            target_position, new_scale = tracker_eval(net, round(s_x), z_features, x_features, target_position, window,
                                                      p)
            # scale damping and saturation
            s_x = max(min_s_x, min(max_s_x, (1 - p.scale_LR) * s_x + p.scale_LR * scaled_instance[int(new_scale)]))
            target_size = (1 - p.scale_LR) * target_size + p.scale_LR * np.array(
                [scaled_target[0, int(new_scale)], scaled_target[1, int(new_scale)]])

        rect_position = np.array(
            [target_position[1] - target_size[1] / 2, target_position[0] - target_size[0] / 2, target_size[1],
             target_size[0]])

        # visualize the tracking results
        # comment for not visualizing
        if i % 50 == 0:
            visualize_tracking_result(rgb_img_uint8, rect_position, 1)

        # output bbox in the original frame coordinates
        o_target_position = target_position
        o_target_size = target_size
        bboxes[i, :] = np.array(
            [o_target_position[1] - o_target_size[1] / 2, o_target_position[0] - o_target_size[0] / 2, o_target_size[1],
             o_target_size[0]])
    # save tracking results
    np.savetxt('./Tracking_Res_RGBT.txt', bboxes, fmt='%.3f')
    print('\n')
    print("Success Rate of the tracker on this sequence: ", evaluate_success_rate(bboxes, gt))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'SiamNet.SiamNet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'torch.nn.modules.pooling.MaxPool2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-2a04516d3442> in <module>()
#      31
#      32     # load sequences
# ---> 33     rgb_img_list, t_img_list, target_position, target_size, gt = load_sequence('/gdrive/MyDrive/hw5/RGB-T234/rainingwaliking')
#      34
#      35     # first frame (Visual + Thermal)
#
# <ipython-input-7-52855f98b04b> in load_sequence(seq_path)
#      37     img_list.sort()
#      38
# ---> 39     groundtruth = open(groundtruthfile, 'r')
#      40     reader = groundtruth.readline()
#      41     region = [float(i) for i in reader.strip().split(",")]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gdrive/MyDrive/hw5/RGB-T234/rainingwaliking/groundtruth_rect.txt'

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw5' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw5.zip" for homework5 in this structure:
# ```
# LeCun_Yann_111134567_hw5
#         |---LeCun_Yann_111134567_hw5_p1.ipynb
#         |---LeCun_Yann_111134567_hw5_p2.ipynb
#         |---LeCun_Yann_111134567_hw5.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's email: ***kgarigapati@cs.stonybrook.edu***. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 3 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.
